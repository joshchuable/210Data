# %%
import numpy as np
np.random.seed(9221999)
import pandas as pd

# %%
df = pd.read_csv('two_digit.csv')
df.head()
df.columns
df.sort(columns='year')
# Out:
#        year  industry_code                               industry_description  \
# 22408  1997             21      Mining, Quarrying, and Oil and Gas Extraction
# 29281  1997             53                 Real Estate and Rental and Leasing
# 29280  1997             61                               Educational Services
# 13265  1997             56  Administrative and Support and Waste Managemen...
# 13266  1997             42                                    Wholesale Trade
# 29234  1997             31                                      Manufacturing
# 13268  1997             61                               Educational Services
# 13261  1997             23                                       Construction
# 29223  1997             22                                          Utilities
# 13280  1997             72                     Accomodation and food services
# 13283  1997             53                 Real Estate and Rental and Leasing
# ...

# %%
df.shape
# Out:
# (37681, 10)

# %%
p = df['industry_code']
p.nunique()
# Out:
# 18

# %%
byindustry = df.groupby(['industry_code','year'])

# %%
byindustry['industry_regulation_index'].mean()
# Out:
# industry_code  year
# 11             1997    4161.410380
#                1998    4261.296111
#                1999    4604.659978
#                2000    4777.860770
#                2001    4947.842147
#                2002    4963.701330
#                2003    4870.720943
#                2004    5015.223047
#                2005    5148.870435
#                2006    5478.831936
#                2007    5645.544544
#                2008    5674.867679
#                2009    2988.750101
#                2010    5420.610405
#                2011    6860.591882
# ...
# 92             1998    4.555420
#                1999    4.280487
#                2000    3.924882
#                2001    4.149868
#                2002    4.031102
#                2003    4.112448
#                2004    4.005449
#                2005    4.018228
#                2006    3.954460
#                2007    3.878933
#                2008    3.931961
#                2009    3.934901
# ...
